# %%
from core.data import load_sess

subj_id = "MR82"
sess_id = "20251107_151529"
_, trial_data, _, _, _ = load_sess(
    subj_id=subj_id,
    sess_id=sess_id,
    tpre=0.5,
    tpost=0.5,
    alignment="choice",
    alignment_ref=None,
    binwidth_ms=25,
    thresh=1,
)
# is min(n.mb, n.mf) < 20?

# %%
td_mb = trial_data[trial_data["strategy"] == 1]
td_mf = trial_data[trial_data["strategy"] == -1]

# %%
td_mb

# %%
td_mf

# %%
trial_data
